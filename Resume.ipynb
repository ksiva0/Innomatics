# %% [markdown]
# # SIVA SANKAR KOMMERLA <img src="https://th.bing.com/th/id/OIP.wGatdTzXf486deAnCWIkwwHaHa?pid=ImgDet&rs=1" align="right" height="150" width="150">
#
#
# * Linkedin : [Linkedin Profile](https://www.linkedin.com/in/siva-sankar-kommerla)
# * E-Mail : sivamaster.siva08@gmail.com
# * Contact No : +91 9347789042
# * Location : Nandyal, Andhra Pradesh
#
#
# ### Career Objective
# ****
# Seeking a challenging and dynamic entry-level position in software field where I can leverage my skills to contribute effectively to a collaborative team. I'm eager to learn, grow and develop my expertise while making a meaningful contribution to the organization's success.
#
# ### Technical Skills
# ****
# * UI/UX Design
# * Figma
# * Java
# * HTML & CSS
#
# ### Experience
# ***
# Technology Developer at <b>MORIPESH</b>                                                                    (Nov 2021- Jan 2023)
# * Moripesh investing in companies that harness technology and innovation to create jobs for the youth in Africa, we are focused on;Education Technology, E-Commerce, Content Creation And Data Connectivity.
#   * I involved in Learnt Africa project, in that I'm done with Server & Domain setup. For that we are using Linux for providing bettercomponents like Storage, Email responding in an huge quantity for customer's, who are ready to learn virtually in Africa continent people's.
#   * Learnt Africa is one of the best flatform for learning virtually to African peoples.
#
# Technology Developer Intern at <b> MORIPESH </b>                  (May 2021 - july 2021)
# * Moripesh investing in companies that harness technology and innovation to create jobs for the youth in Africa, we are focused on;Education Technology, E-Commerce, Content Creation And Data Connectivity.
#   * I'm worked in Veesh Africa Project, is an both Web & Mobile Application project. I done with creating Mockup's by using Figma ( Software ). Figma is an perfect software tool for implementing UI/UX Designs in best components for easily understanding by everyone.
#   * Veesh Africa project can also publishing in E-Commerce platform through WordPress. In WordPress, I'm moved with an plugin installation for responding to the customer's on getting updates based on payments, product available notifications through Mail messages and then moving with designing the website page in an WordPress.
#
# ### Education
# ***
# Tadipatri Engineering College  -  2022
#   * B-Tech (Computer Science & Engineering)
#   * Percentage - 65%
#
# J.C.N.R.M Junior College  - 2018
#   * 12th - MPC
#   * Percentage - 79%
#
# Sir Visweswarah E/M High School  - 2016
#   * SSC
#   * Percentage - 82%
#
# ### Skills
# ***
# * Critical Thinking
# * Problem Solving
# * Time Management
# * Decision Making
#
# ### Achievements & Awards
# ***
# * Got gold medal in social media marketing internship nationally with 11th rank, conducted by <b>TECHFEST, IIT Bombay</b>
# * Got 3rd prize on poster presentation in occation of <b>Environmental Day</b>, conducted by <b>Gate Institute of Technology</b>
